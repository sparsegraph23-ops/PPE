# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.13 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5090, 32102MiB)
# Setup complete ✅ (32 CPUs, 62.6 GB RAM, 354.0/914.8 GB disk)

# %%
from roboflow import Roboflow
from ultralytics import YOLO

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 5090

# %%
rf = Roboflow(api_key="VJylJVIRAbn8Lw1bqs7L")
project = rf.workspace("fyp_23_2026-uor_foe").project("ppe-detection-farqh")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
model = YOLO("yolo11l.pt")

# %%
epochs = 150

# %%
model_size = "m"

# %%
from datetime import datetime
current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

results = model.train(
    data="/home/ai_vison/Desktop/PPE/model_finetune/person/PPE-Detection-4/data.yaml",
    epochs=epochs,
    imgsz=640,
    batch=16,
    device=0,
    project="/home/ai_vison/Desktop/PPE/model_finetune/person/runs",
    name=f"{current_time} {epochs} {model_size}"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.60 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.12.13 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5090, 32102MiB)
# ...

# %%
# import numpy
# import ultralytics

# print("NumPy:", numpy.__version__)
# print("Ultralytics:", ultralytics.__version__)
