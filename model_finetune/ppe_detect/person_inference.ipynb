# %%
from ultralytics import YOLO

# %%
model_200_l = YOLO(model="/home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/runs/2026-06-02 18:26:19 200 l/weights/best.pt")

# %%
#Run batched inference on a list of images
results = model_200_l.predict(source="/home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample", imgsz=[455, 171], classes=[0,1,2], show=True, iou=0.5, save=True)  # return a list of Results objects
# Out:
# QFontDatabase: Cannot find font directory /home/ai_vison/miniconda3/envs/ppe/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ai_vison/miniconda3/envs/ppe/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ai_vison/miniconda3/envs/ppe/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ai_vison/miniconda3/envs/ppe/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ai_vison/miniconda3/envs/ppe/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# WARNING ⚠️ imgsz=[455, 171] must be multiple of max stride 32, updating to [480, 192]
# image 1/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_289_0.jpg: 288x192 1 helmet, 1 jacket, 18.7ms
# image 2/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_290_0.jpg: 352x192 1 helmet, 18.4ms
# image 3/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_291_0.jpg: 416x192 1 helmet, 1 jacket, 19.3ms
# image 4/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_294_0.jpg: 224x192 1 helmet, 1 jacket, 20.0ms
# image 5/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_296_0.jpg: 288x192 1 helmet, 4.9ms
# image 6/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_297_0.jpg: 448x192 1 helmet, 1 jacket, 18.8ms
# image 7/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_297_1.jpg: 320x192 1 helmet, 2 jackets, 18.5ms
# image 8/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_299_0.jpg: 256x192 1 helmet, 18.4ms
# image 9/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_301_1.jpg: 480x128 1 boot, 1 helmet, 18.7ms
# image 10/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_303_0.jpg: 352x192 1 boot, 1 helmet, 1 jacket, 4.6ms
# image 11/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_303_1.jpg: 480x192 1 jacket, 8.7ms
# image 12/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_307_0.jpg: 480x192 1 jacket, 4.8ms
# image 13/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_308_0.jpg: 480x192 1 helmet, 4.8ms
# image 14/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_308_1.jpg: 480x192 1 helmet, 4.6ms
# image 15/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_309_0.jpg: 288x192 1 jacket, 5.0ms
# image 16/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_310_0.jpg: 448x192 1 helmet, 4.8ms
# image 17/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_311_0.jpg: 288x192 1 helmet, 1 jacket, 11.5ms
# image 18/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_312_0.jpg: 480x192 1 jacket, 5.2ms
# image 19/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_312_1.jpg: 480x192 1 jacket, 4.7ms
# image 20/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_312_2.jpg: 480x160 1 jacket, 18.7ms
# image 21/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_313_0.jpg: 384x192 1 helmet, 18.4ms
# image 22/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_314_0.jpg: 480x160 1 boot, 2 helmets, 1 jacket, 5.0ms
# image 23/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_314_1.jpg: 352x192 2 helmets, 1 jacket, 4.6ms
# image 24/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_314_2.jpg: 480x192 1 helmet, 1 jacket, 5.5ms
# image 25/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_316_0.jpg: 352x192 1 helmet, 5.2ms
# image 26/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_316_1.jpg: 480x160 1 helmet, 5.3ms
# image 27/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_317_0.jpg: 288x192 1 helmet, 1 jacket, 4.7ms
# image 28/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_318_0.jpg: 288x192 1 jacket, 4.3ms
# image 29/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_319_0.jpg: 320x192 1 helmet, 1 jacket, 4.7ms
# image 30/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_320_1.jpg: 480x192 (no detections), 5.1ms
# image 31/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_321_0.jpg: 352x192 (no detections), 4.8ms
# image 32/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_323_0.jpg: 480x192 1 jacket, 4.9ms
# image 33/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_324_0.jpg: 224x192 (no detections), 4.8ms
# image 34/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_326_0.jpg: 480x160 1 helmet, 1 jacket, 4.9ms
# image 35/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_326_1.jpg: 480x160 1 helmet, 1 jacket, 4.7ms
# image 36/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_326_2.jpg: 480x160 1 helmet, 1 jacket, 4.9ms
# image 37/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_328_0.jpg: 480x192 1 helmet, 1 jacket, 4.7ms
# image 38/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_328_1.jpg: 480x160 1 helmet, 1 jacket, 5.0ms
# image 39/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_49_0.jpg: 288x192 1 helmet, 5.0ms
# image 40/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_50_0.jpg: 288x192 1 helmet, 4.5ms
# image 41/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_634_0.jpg: 320x192 2 boots, 1 helmet, 4.8ms
# image 42/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_820_1.jpg: 480x96 1 helmet, 19.5ms
# image 43/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_824_0.jpg: 224x192 1 helmet, 4.7ms
# image 44/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_838_0.jpg: 480x96 1 boot, 1 jacket, 4.8ms
# image 45/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_838_1.jpg: 352x192 1 boot, 1 helmet, 1 jacket, 5.0ms
# image 46/46 /home/ai_vison/Desktop/PPE/model_finetune/ppe_detect/inf_sample/extracted_886_0.jpg: 480x96 1 boot, 1 helmet, 1 jacket, 4.9ms
# Speed: 0.5ms preprocess, 8.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 96)
# Results saved to runs/detect/predict

# %%
#inf_img = model_200_l.predict(source="/home/ai_vison/Desktop/PPE/model_finetune/person/sample1/helmet_jacket_06384.jpg", imgsz=640, classes=[0,1], save=True, show=True, conf=0.60)  # return a list of Results objects

# %%
#print(inf_img[0])

# %%
# for x in range(5):
#     print(inf_img[0].boxes[x])

# %%
# for x in range(5):
#     print(inf_img[0].boxes[x].conf)

# %%
# inf_img[0].boxes[2].xyxy

# %%
# import torch
# import torchvision

# # Your first box in xyxy format
# box1 = torch.tensor([[ 13.1572, 213.5504, 335.6323, 639.7269]], device='cuda:0')

# # Example second box to compare against
# box2 = torch.tensor([[ 13.2525, 211.4725, 319.5779, 639.6135]], device='cuda:0') 

# def calculate_iou(box1, box2):
#     # box_iou compares all boxes in box1 to all boxes in box2
#     iou = torchvision.ops.box_iou(box1, box2)
#     return iou

# iou = calculate_iou(box1, box2)
# print("IoU:", iou.item())

# %%
# def is_overlap(box1, box2):
#     iou = calculate_iou(box1, box2)
#     print(iou)
#     return iou > 0.7

# def non_max_suppression(boxes):
#     # Sort boxes by confidence in descending order
#     try: 
#         boxes = sorted(boxes, key=lambda x: x.conf, reverse=True)
#         keep = []

#         while boxes:
#             # Take the box with highest confidence
#             current = boxes.pop(0)
#             keep.append(current)

#             # Remove boxes that overlap too much with current box
#             boxes = [box for box in boxes if
#                         not is_overlap(current.xyxy, box.xyxy)]

#         return keep
#     except Exception as e:
#         print(f"An error occurred during non-max suppression: {e}")
#         return []

# %%
#keep = non_max_suppression(inf_img[0].boxes)

# %%
#len(keep)

# %%
# for k in keep:
#     print(k.conf)

# %%
# # import cv2
# import matplotlib.pyplot as plt

# # The original image is stored in BGR format by default
# orig_image = inf_img[0].orig_img
# # Convert to RGB since matplotlib expects RGB colors for visualization
# orig_image_rgb = cv2.cvtColor(orig_image, cv2.COLOR_BGR2RGB)

# # Create a sequence of subplots
# fig, axes = plt.subplots(1, len(keep), figsize=(15, 5))

# # Handle the case where there is only 1 box kept (axes won't be a list)
# if len(keep) == 1:
#     axes = [axes]

# for i, k in enumerate(keep):
#     # Extract coordinates and convert them to integers
#     x1, y1, x2, y2 = map(int, k.xyxy[0].tolist())
    
#     # Extract out the cropped section using NumPy slicing: image[y_start:y_end, x_start:x_end]
#     cropped_img = orig_image_rgb[y1:y2, x1:x2]
    
#     # Plot the extracted image crop
#     axes[i].imshow(cropped_img)
#     axes[i].set_title(f"Conf: {k.conf.item():.2f}")
#     axes[i].axis('off')

# plt.tight_layout()
# plt.show()

# %%
# import os
# import cv2

# # Create a directory to save the extracted images
# save_dir = "extracted_objects"
# os.makedirs(save_dir, exist_ok=True)

# for i, k in enumerate(keep):
#     # Extract coordinates and convert them to integers
#     x1, y1, x2, y2 = map(int, k.xyxy[0].tolist())
    
#     # Crop from the original BGR image
#     cropped_bgr = inf_img[0].orig_img[y1:y2, x1:x2]
    
#     # Create a filename with the index and confidence score
#     filename = os.path.join(save_dir, f"extracted_{i}_conf_{k.conf.item():.2f}.jpg")
    
#     # Save the image to disk
#     cv2.imwrite(filename, cropped_bgr)
#     print(f"Saved: {filename}")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
