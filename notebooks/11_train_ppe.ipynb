# %%
# --- repo bootstrap -------------------------------------------------------
# Resolves the repository root and chdirs to it, so every path below is
# repo-relative and this notebook runs from any checkout location.
import os
from pathlib import Path

ROOT = Path.cwd().resolve()
while not (ROOT / ".git").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
os.chdir(ROOT)
print("repo root:", ROOT)

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.13 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5090, 32102MiB)
# Setup complete ✅ (32 CPUs, 62.6 GB RAM, 298.1/914.8 GB disk)

# %%
from roboflow import Roboflow
from ultralytics import YOLO

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 5090

# %%
rf = Roboflow(api_key="VJylJVIRAbn8Lw1bqs7L")
project = rf.workspace("fyp_23_2026-uor_foe").project("ppe_objects")
version = project.version(5)
dataset = version.download("yolov11", location="data/raw/ppe")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
model = YOLO("yolo11l.pt")

# %%
epochs = 220

# %%
model_size = "l"

# %%
from datetime import datetime
current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

results = model.train(
    data="data/raw/ppe/data.yaml",
    epochs=epochs,
    imgsz=[455, 171],
    batch=16,
    device=0,
    project="experiments/ppe",
    name=f"{current_time} {epochs} {model_size}"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.60 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.12.13 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5090, 32102MiB)
# ...

# %%
# import numpy
# import ultralytics

# print("NumPy:", numpy.__version__)
# print("Ultralytics:", ultralytics.__version__)
