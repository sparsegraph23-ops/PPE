# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.60 🚀 Python-3.13.13 torch-2.12.0.dev20260407+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32111MiB)
# Setup complete ✅ (32 CPUs, 62.6 GB RAM, 261.3/914.8 GB disk)

# %%
from roboflow import Roboflow
from ultralytics import YOLO

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 5090

# %%
rf = Roboflow(api_key="VJylJVIRAbn8Lw1bqs7L")
project = rf.workspace("fyp_23_2026-uor_foe").project("ppe_objects")
version = project.version(5)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
model = YOLO("yolo26m.pt")
epochs = 150
model_size = "m"

from datetime import datetime
current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

results = model.train(
    data="/home/hri_multimodal/Desktop/ppe_detect/ppe_objects-5/data.yaml",
    epochs=epochs,
    imgsz=[455, 171],
    batch=16,
    device=0,
    project="/home/hri_multimodal/Desktop/ppe_detect/runs",
    name=f"{current_time} {epochs} {model_size}"
)
# Out:
# Ultralytics 8.4.60 🚀 Python-3.13.13 torch-2.12.0.dev20260407+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32111MiB)
# ...

# %%
model = YOLO("yolo26m.pt")
epochs = 170
model_size = "m"

from datetime import datetime
current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

results = model.train(
    data="/home/hri_multimodal/Desktop/ppe_detect/ppe_objects-5/data.yaml",
    epochs=epochs,
    imgsz=[455, 171],
    batch=16,
    device=0,
    project="/home/hri_multimodal/Desktop/ppe_detect/runs",
    name=f"{current_time} {epochs} {model_size}"
)
# Out:
# Ultralytics 8.4.60 🚀 Python-3.13.13 torch-2.12.0.dev20260407+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32111MiB)
# ...

# %%
model = YOLO("yolo26m.pt")
epochs = 200
model_size = "m"

from datetime import datetime
current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

results = model.train(
    data="/home/hri_multimodal/Desktop/ppe_detect/ppe_objects-5/data.yaml",
    epochs=epochs,
    imgsz=[455, 171],
    batch=16,
    device=0,
    project="/home/hri_multimodal/Desktop/ppe_detect/runs",
    name=f"{current_time} {epochs} {model_size}"
)
# Out:
# Ultralytics 8.4.60 🚀 Python-3.13.13 torch-2.12.0.dev20260407+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32111MiB)
# ...

# %%
model = YOLO("yolo26m.pt")
epochs = 220
model_size = "m"

from datetime import datetime
current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

results = model.train(
    data="/home/hri_multimodal/Desktop/ppe_detect/ppe_objects-5/data.yaml",
    epochs=epochs,
    imgsz=[455, 171],
    batch=16,
    device=0,
    project="/home/hri_multimodal/Desktop/ppe_detect/runs",
    name=f"{current_time} {epochs} {model_size}"
)
# Out:
# Ultralytics 8.4.60 🚀 Python-3.13.13 torch-2.12.0.dev20260407+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32111MiB)
# ...

# %%
model = YOLO("yolo26l.pt")
epochs = 150
model_size = "l"

from datetime import datetime
current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

results = model.train(
    data="/home/hri_multimodal/Desktop/ppe_detect/ppe_objects-5/data.yaml",
    epochs=epochs,
    imgsz=[455, 171],
    batch=16,
    device=0,
    project="/home/hri_multimodal/Desktop/ppe_detect/runs",
    name=f"{current_time} {epochs} {model_size}"
)
# Out:
# ...
# Ultralytics 8.4.60 🚀 Python-3.13.13 torch-2.12.0.dev20260407+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32111MiB)
# ...

# %%
model = YOLO("yolo26l.pt")
epochs = 170
model_size = "l"

from datetime import datetime
current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

results = model.train(
    data="/home/hri_multimodal/Desktop/ppe_detect/ppe_objects-5/data.yaml",
    epochs=epochs,
    imgsz=[455, 171],
    batch=16,
    device=0,
    project="/home/hri_multimodal/Desktop/ppe_detect/runs",
    name=f"{current_time} {epochs} {model_size}"
)
# Out:
# Ultralytics 8.4.60 🚀 Python-3.13.13 torch-2.12.0.dev20260407+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32111MiB)
# ...

# %%
model = YOLO("yolo26l.pt")
epochs = 200
model_size = "l"

from datetime import datetime
current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

results = model.train(
    data="/home/hri_multimodal/Desktop/ppe_detect/ppe_objects-5/data.yaml",
    epochs=epochs,
    imgsz=[455, 171],
    batch=16,
    device=0,
    project="/home/hri_multimodal/Desktop/ppe_detect/runs",
    name=f"{current_time} {epochs} {model_size}"
)
# Out:
# Ultralytics 8.4.60 🚀 Python-3.13.13 torch-2.12.0.dev20260407+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32111MiB)
# ...

# %%
model = YOLO("yolo26l.pt")
epochs = 220
model_size = "l"

from datetime import datetime
current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

results = model.train(
    data="/home/hri_multimodal/Desktop/ppe_detect/ppe_objects-5/data.yaml",
    epochs=epochs,
    imgsz=[455, 171],
    batch=16,
    device=0,
    project="/home/hri_multimodal/Desktop/ppe_detect/runs",
    name=f"{current_time} {epochs} {model_size}"
)
# Out:
# Ultralytics 8.4.60 🚀 Python-3.13.13 torch-2.12.0.dev20260407+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32111MiB)
# ...
